# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# fileNameNN = '/workdir/huichi/NF-C-VAE/data_save/LHCO2020_cB-VAE_events.csv'
fileNameNN = '/workdir/huichi/NF-C-VAE/data_save/gen_train.csv'
dfNN = pd.read_csv(fileNameNN, delimiter = ' ', header=None, index_col=False)

# %%
title = ['mj1', 'deltamj', 'tau21j1', 'tau21j2']
print(dfNN.shape)
plt.hist(dfNN[3], bins=50)
plt.title(title[3], fontsize=20)
plt.show()
# Out:
# (499889, 4)

# %%
mean = np.load("/workdir/huichi/NF-C-VAE/model_save/best_latent_mean.npy", allow_pickle=True)
mean = np.concatenate(mean, axis=0)
print(mean)
# Out:
# [[-6.0744089e-01  1.0811430e-01 -1.3853157e-01 ...  1.1801782e-01
#    2.1468703e-01  1.7058125e-01]
#  [ 4.6932209e-01  3.3006445e-02 -2.8189871e-01 ... -2.8651670e-01
#   -2.7476907e-01  2.0594823e-01]
#  [ 3.6586711e-01 -2.5836340e-01 -3.3160123e-01 ... -3.6239654e-01
#    1.6556442e-01  1.7837706e-01]
#  ...
#  [ 6.0138268e-06 -7.0011038e-06 -6.1963228e-06 ... -5.1720167e-06
#   -2.7037182e-05  9.2722366e-06]
#  [ 6.0138268e-06 -7.0011038e-06 -6.1963228e-06 ... -5.1720167e-06
#   -2.7037182e-05  9.2722366e-06]
#  [ 6.0138268e-06 -7.0011038e-06 -6.1963228e-06 ... -5.1720167e-06
#   -2.7037182e-05  9.2722366e-06]]

# %%
epoch = np.arange(0,100)
train_loss = np.load("/workdir/huichi/NF-C-VAE/data_save/test_ConvF_train_loss.npy", allow_pickle=True)
val_loss = np.load("/workdir/huichi/NF-C-VAE/data_save/test_ConvF_val_loss.npy", allow_pickle=True)
plt.plot(epoch, train_loss, '-', label='train')
plt.plot(epoch, val_loss, '-', label='val')
plt.yscale('log')
plt.legend()

# %%
mean2 = pd.read_csv("/workdir/huichi/DeepEvents/LHCO2020/6var/cbvae_LHCO2020_latent_mean_20d_e-6.csv")
mean_val = mean2.values
mean_val[0]
# Out:
# array(['-1.563642174005508423e-03 -1.669387146830558777e-02 1.763635039329528809e+00 -1.298933506011962891e+00 2.466091394424438477e+00 -8.181557059288024902e-03 4.878496751189231873e-03 7.381353527307510376e-03 -8.742279373109340668e-03 -1.884104683995246887e-03 2.993950545787811279e-01 2.496533542871475220e-01 -7.267200853675603867e-03 -6.259363144636154175e-04 -9.261817671358585358e-03 4.081878811120986938e-03 9.909184649586677551e-03 -1.054603815078735352e+00 -1.175837032496929169e-02 3.638323396444320679e-03'],
#       dtype=object)
