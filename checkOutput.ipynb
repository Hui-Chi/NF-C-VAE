# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
epoch = np.arange(0,100)
train_loss = np.load("/workdir/huichi/NF-C-VAE/data_save/6var_IAF_train_loss.npy", allow_pickle=True)
val_loss = np.load("/workdir/huichi/NF-C-VAE/data_save/6var_IAF_val_loss.npy", allow_pickle=True)
plt.plot(epoch, train_loss, '-', label='total_loss_train')
plt.plot(epoch, val_loss, '-', label='total_loss_val')
plt.yscale('log')
plt.legend()

# %%
epoch = np.arange(0,100)
train_kl = np.load("/workdir/huichi/NF-C-VAE/data_save/6var_MAF_train_kl.npy", allow_pickle=True)
val_kl = np.load("/workdir/huichi/NF-C-VAE/data_save/6var_MAF_val_kl.npy", allow_pickle=True)
plt.plot(epoch, train_kl, '-', label='kl_loss_train')
plt.plot(epoch, val_kl, '-', label='kl_loss_val')
plt.yscale('log')
plt.legend()

# %%
epoch = np.arange(0,100)
plt.plot(epoch, train_loss - train_kl, '-', label='mse_loss_train')
plt.plot(epoch, val_loss - val_kl, '-', label='mse_loss_val')
plt.yscale('log')
plt.legend()

# %%
fileNameNN = '/workdir/huichi/NF-C-VAE/data_save/LHCO2020_cB-VAE_events_6var_MAF_SB.csv'
# fileNameNN = '/workdir/huichi/NF-C-VAE/data_save/gen_train_noCond.csv'
dfNN = pd.read_csv(fileNameNN, delimiter = ' ', header=None, index_col=False)

# %%
title = ['mj1', 'deltamj', 'tau21j1', 'tau21j2', 'tau32j1', 'tau32j2']
print(dfNN.shape)
plt.hist(dfNN[0], bins=50)
plt.title(title[0], fontsize=20)
plt.show()
# Out:
# (878648, 6)
